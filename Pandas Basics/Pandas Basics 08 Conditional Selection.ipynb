# %%
import pandas as pd
import numpy as np

# %%
my_df = pd.read_csv('Bus_Breakdown_and_Delays.csv')
my_df
# Out:
#        School_Year  Busbreakdown_ID             Run_Type  Bus_No Route_Number  \
# 0        2015-2016          1224901             Pre-K/EI     811            1
# 1        2015-2016          1225098             Pre-K/EI    9302            1
# 2        2015-2016          1215800             Pre-K/EI     358            2
# 3        2015-2016          1215511             Pre-K/EI     331            2
# 4        2015-2016          1215828             Pre-K/EI     332            2
# ...            ...              ...                  ...     ...          ...
# 147967   2016-2017          1338452             Pre-K/EI    9345            2
# 147968   2016-2017          1341521             Pre-K/EI    0001            5
# 147969   2016-2017          1353044    Special Ed PM Run  GC0112         X928
# 147970   2016-2017          1353045    Special Ed PM Run   5525D         Q920
# 147971   2016-2017          1353046  Project Read PM Run    2530         K617
#
# ...

# %%
# Conditional Selection
# > < = >= <= etc
my_df == 'Heavy Traffic'
# Out:
#         School_Year  Busbreakdown_ID  Run_Type  Bus_No  Route_Number  Reason  \
# 0             False            False     False   False         False   False
# 1             False            False     False   False         False    True
# 2             False            False     False   False         False    True
# 3             False            False     False   False         False   False
# 4             False            False     False   False         False   False
# ...             ...              ...       ...     ...           ...     ...
# 147967        False            False     False   False         False    True
# 147968        False            False     False   False         False    True
# 147969        False            False     False   False         False    True
# 147970        False            False     False   False         False   False
# 147971        False            False     False   False         False   False
#
# ...

# %%
# Return Dataframe with data
my_df[my_df == 'Heavy Traffic']
# Out:
#        School_Year  Busbreakdown_ID Run_Type Bus_No Route_Number  \
# 0              NaN              NaN      NaN    NaN          NaN
# 1              NaN              NaN      NaN    NaN          NaN
# 2              NaN              NaN      NaN    NaN          NaN
# 3              NaN              NaN      NaN    NaN          NaN
# 4              NaN              NaN      NaN    NaN          NaN
# ...            ...              ...      ...    ...          ...
# 147967         NaN              NaN      NaN    NaN          NaN
# 147968         NaN              NaN      NaN    NaN          NaN
# 147969         NaN              NaN      NaN    NaN          NaN
# 147970         NaN              NaN      NaN    NaN          NaN
# 147971         NaN              NaN      NaN    NaN          NaN
#
#                Reason Schools_Serviced Occurred_On Created_On Boro  ...  \
# 0                 NaN              NaN         NaN        NaN  NaN  ...
# ...

# %%
# Return Data with certain columns
my_df[my_df == 'Heavy Traffic']['Reason']
# Out:
# 0                   NaN
# 1         Heavy Traffic
# 2         Heavy Traffic
# 3                   NaN
# 4                   NaN
#               ...
# 147967    Heavy Traffic
# 147968    Heavy Traffic
# 147969    Heavy Traffic
# 147970              NaN
# 147971              NaN
# Name: Reason, Length: 147972, dtype: object

# %%
my_df[my_df == 'Heavy Traffic'][['Reason',"Bus_No"]]
# Out:
#                Reason Bus_No
# 0                 NaN    NaN
# 1       Heavy Traffic    NaN
# 2       Heavy Traffic    NaN
# 3                 NaN    NaN
# 4                 NaN    NaN
# ...               ...    ...
# 147967  Heavy Traffic    NaN
# 147968  Heavy Traffic    NaN
# 147969  Heavy Traffic    NaN
# 147970            NaN    NaN
# 147971            NaN    NaN
#
# [147972 rows x 2 columns]

# %%
my_df[my_df == 5]['Number_Of_Students_On_The_Bus']
# Out:
# 0         5.0
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
#          ...
# 147967    NaN
# 147968    NaN
# 147969    NaN
# 147970    NaN
# 147971    NaN
# Name: Number_Of_Students_On_The_Bus, Length: 147972, dtype: float64
