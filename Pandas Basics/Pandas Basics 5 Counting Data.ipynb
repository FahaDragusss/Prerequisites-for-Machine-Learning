# %%
import pandas as pd
import numpy as np

# %%
my_df = pd.read_csv('Bus_Breakdown_and_Delays.csv')
my_df
# Out:
#        School_Year  Busbreakdown_ID             Run_Type  Bus_No Route_Number  \
# 0        2015-2016          1224901             Pre-K/EI     811            1
# 1        2015-2016          1225098             Pre-K/EI    9302            1
# 2        2015-2016          1215800             Pre-K/EI     358            2
# 3        2015-2016          1215511             Pre-K/EI     331            2
# 4        2015-2016          1215828             Pre-K/EI     332            2
# ...            ...              ...                  ...     ...          ...
# 147967   2016-2017          1338452             Pre-K/EI    9345            2
# 147968   2016-2017          1341521             Pre-K/EI    0001            5
# 147969   2016-2017          1353044    Special Ed PM Run  GC0112         X928
# 147970   2016-2017          1353045    Special Ed PM Run   5525D         Q920
# 147971   2016-2017          1353046  Project Read PM Run    2530         K617
#
# ...

# %%
# Count distinct Values - Descending
my_df['How_Long_Delayed'].value_counts()
# Out:
# How_Long_Delayed
# 20 MINS       5662
# 30 MINS       4542
# 30 minutes    3650
# 15 mins       3522
# 30MINS        3199
#               ...
# 45 MON           1
# 18 mins          1
# 146              1
# 1HOUR15MIN       1
# 45 MINIUTE       1
# Name: count, Length: 1863, dtype: int64

# %%
my_df['How_Long_Delayed'].value_counts(ascending=True)
# Out:
# How_Long_Delayed
# 45 MINIUTE       1
# 18MINS           1
# 9MINS            1
# 30 minute        1
# .30-45           1
#               ...
# 30MINS        3199
# 15 mins       3522
# 30 minutes    3650
# 30 MINS       4542
# 20 MINS       5662
# Name: count, Length: 1863, dtype: int64

# %%
my_df['How_Long_Delayed'].value_counts(dropna=False)
# Out:
# How_Long_Delayed
# NaN           21630
# 20 MINS        5662
# 30 MINS        4542
# 30 minutes     3650
# 15 mins        3522
#               ...
# 45 MON            1
# 18 mins           1
# 146               1
# 1HOUR15MIN        1
# 45 MINIUTE        1
# Name: count, Length: 1864, dtype: int64

# %%
my_df['How_Long_Delayed'].value_counts(normalize=True)
# Out:
# How_Long_Delayed
# 20 MINS       0.044815
# 30 MINS       0.035950
# 30 minutes    0.028890
# 15 mins       0.027877
# 30MINS        0.025320
#                 ...
# 45 MON        0.000008
# 18 mins       0.000008
# 146           0.000008
# 1HOUR15MIN    0.000008
# 45 MINIUTE    0.000008
# Name: proportion, Length: 1863, dtype: float64

# %%
my_df['How_Long_Delayed'].value_counts()['20 MINS']
# Out:
# 5662

# %%
my_df.groupby('How_Long_Delayed').size()
# Out:
# How_Long_Delayed
# !0 mins       3
# ------        1
# -------       2
# ----------    1
# -10           2
#              ..
# minutes       1
# one hour      1
# traffic       1
# unk           1
# unknown       1
# Length: 1863, dtype: int64

# %%
my_df.groupby('How_Long_Delayed').count()
# Out:
#                   School_Year  Busbreakdown_ID  Run_Type  Bus_No  \
# How_Long_Delayed
# !0 mins                     3                3         3       3
# ------                      1                1         1       1
# -------                     2                2         2       2
# ----------                  1                1         1       1
# -10                         2                2         2       2
# ...                       ...              ...       ...     ...
# minutes                     1                1         1       1
# one hour                    1                1         1       1
# traffic                     1                1         1       1
# unk                         1                1         1       1
# unknown                     1                1         1       1
#
#                   Route_Number  Reason  Schools_Serviced  Occurred_On  \
# How_Long_Delayed
# !0 mins                      3       3                 3            3
# ...

# %%
my_df.apply(pd.value_counts)
# Out:
#                         School_Year  Busbreakdown_ID  Run_Type  Bus_No  \
# 2015-2016                   63184.0              NaN       NaN     NaN
# 2016-2017                   83141.0              NaN       NaN     NaN
# 2017-2018                    1646.0              NaN       NaN     NaN
# 2019-2020                       1.0              NaN       NaN     NaN
# 1224901                         NaN              1.0       NaN     NaN
# ...                             ...              ...       ...     ...
# 05/25/2017 04:37:37 PM          NaN              NaN       NaN     NaN
# Running Late                    NaN              NaN       NaN     NaN
# Breakdown                       NaN              NaN       NaN     NaN
# School-Age                      NaN              NaN       NaN     NaN
# Pre-K                           NaN              NaN       NaN     NaN
#
#                         Route_Number  Reason  Schools_Serviced  Occurred_On  \
# ...
