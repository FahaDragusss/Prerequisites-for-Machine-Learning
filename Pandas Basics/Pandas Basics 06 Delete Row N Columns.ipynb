# %%
import pandas as pd
import numpy as np

# %%
my_df = pd.read_csv('Bus_Breakdown_and_Delays.csv')
my_df
# Out:
#        School_Year  Busbreakdown_ID             Run_Type  Bus_No Route_Number  \
# 0        2015-2016          1224901             Pre-K/EI     811            1
# 1        2015-2016          1225098             Pre-K/EI    9302            1
# 2        2015-2016          1215800             Pre-K/EI     358            2
# 3        2015-2016          1215511             Pre-K/EI     331            2
# 4        2015-2016          1215828             Pre-K/EI     332            2
# ...            ...              ...                  ...     ...          ...
# 147967   2016-2017          1338452             Pre-K/EI    9345            2
# 147968   2016-2017          1341521             Pre-K/EI    0001            5
# 147969   2016-2017          1353044    Special Ed PM Run  GC0112         X928
# 147970   2016-2017          1353045    Special Ed PM Run   5525D         Q920
# 147971   2016-2017          1353046  Project Read PM Run    2530         K617
#
# ...

# %%
my_df2 = my_df.loc[0:4]
my_df2
# Out:
#   School_Year  Busbreakdown_ID  Run_Type Bus_No Route_Number         Reason  \
# 0   2015-2016          1224901  Pre-K/EI    811            1          Other
# 1   2015-2016          1225098  Pre-K/EI   9302            1  Heavy Traffic
# 2   2015-2016          1215800  Pre-K/EI    358            2  Heavy Traffic
# 3   2015-2016          1215511  Pre-K/EI    331            2          Other
# 4   2015-2016          1215828  Pre-K/EI    332            2          Other
#
#   Schools_Serviced             Occurred_On              Created_On   Boro  \
# 0             C353  10/26/2015 08:30:00 AM  10/26/2015 08:40:00 AM  Bronx
# 1             C814  10/27/2015 07:10:00 AM  10/27/2015 07:11:00 AM  Bronx
# 2             C195  09/18/2015 07:36:00 AM  09/18/2015 07:38:00 AM  Bronx
# 3             C178  09/17/2015 08:08:00 AM  09/17/2015 08:12:00 AM  Bronx
# 4             S176  09/18/2015 07:39:00 AM  09/18/2015 07:45:00 AM  Bronx
#
#    ... How_Long_Delayed Number_Of_Students_On_The_Bus  \
# ...

# %%
my_df2.insert(1,'Autonomous',[False]*len(my_df2),True)
my_df2
# Out:
#   School_Year  Autonomous  Autonomous  Busbreakdown_ID  Run_Type Bus_No  \
# 0   2015-2016       False       False          1224901  Pre-K/EI    811
# 1   2015-2016       False       False          1225098  Pre-K/EI   9302
# 2   2015-2016       False       False          1215800  Pre-K/EI    358
# 3   2015-2016       False       False          1215511  Pre-K/EI    331
# 4   2015-2016       False       False          1215828  Pre-K/EI    332
#
#   Route_Number         Reason Schools_Serviced             Occurred_On  ...  \
# 0            1          Other             C353  10/26/2015 08:30:00 AM  ...
# 1            1  Heavy Traffic             C814  10/27/2015 07:10:00 AM  ...
# 2            2  Heavy Traffic             C195  09/18/2015 07:36:00 AM  ...
# 3            2          Other             C178  09/17/2015 08:08:00 AM  ...
# 4            2          Other             S176  09/18/2015 07:39:00 AM  ...
#
#   How_Long_Delayed Number_Of_Students_On_The_Bus  \
# ...

# %%
# Removing columns
my_df2.drop('Autonomous', axis=1, )
# Out:
#   School_Year  Busbreakdown_ID  Run_Type Bus_No Route_Number         Reason  \
# 0   2015-2016          1224901  Pre-K/EI    811            1          Other
# 1   2015-2016          1225098  Pre-K/EI   9302            1  Heavy Traffic
# 2   2015-2016          1215800  Pre-K/EI    358            2  Heavy Traffic
# 3   2015-2016          1215511  Pre-K/EI    331            2          Other
# 4   2015-2016          1215828  Pre-K/EI    332            2          Other
#
#   Schools_Serviced             Occurred_On              Created_On   Boro  \
# 0             C353  10/26/2015 08:30:00 AM  10/26/2015 08:40:00 AM  Bronx
# 1             C814  10/27/2015 07:10:00 AM  10/27/2015 07:11:00 AM  Bronx
# 2             C195  09/18/2015 07:36:00 AM  09/18/2015 07:38:00 AM  Bronx
# 3             C178  09/17/2015 08:08:00 AM  09/17/2015 08:12:00 AM  Bronx
# 4             S176  09/18/2015 07:39:00 AM  09/18/2015 07:45:00 AM  Bronx
#
#    ... How_Long_Delayed Number_Of_Students_On_The_Bus  \
# ...

# %%
my_df2
# Out:
#   School_Year  Busbreakdown_ID  Run_Type Bus_No Route_Number         Reason  \
# 0   2015-2016          1224901  Pre-K/EI    811            1          Other
# 1   2015-2016          1225098  Pre-K/EI   9302            1  Heavy Traffic
# 2   2015-2016          1215800  Pre-K/EI    358            2  Heavy Traffic
# 3   2015-2016          1215511  Pre-K/EI    331            2          Other
# 4   2015-2016          1215828  Pre-K/EI    332            2          Other
#
#   Schools_Serviced             Occurred_On              Created_On   Boro  \
# 0             C353  10/26/2015 08:30:00 AM  10/26/2015 08:40:00 AM  Bronx
# 1             C814  10/27/2015 07:10:00 AM  10/27/2015 07:11:00 AM  Bronx
# 2             C195  09/18/2015 07:36:00 AM  09/18/2015 07:38:00 AM  Bronx
# 3             C178  09/17/2015 08:08:00 AM  09/17/2015 08:12:00 AM  Bronx
# 4             S176  09/18/2015 07:39:00 AM  09/18/2015 07:45:00 AM  Bronx
#
#    ... How_Long_Delayed Number_Of_Students_On_The_Bus  \
# ...

# %%
# Remove it such that it doesnt appear again
my_df2.drop('Autonomous',axis=1,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[39], line 2
#       1 # Remove it such that it doesnt appear again
# ----> 2 my_df2.drop('Autonomous',axis=1,inplace=True)
#
# File c:\Users\fahad\anaconda3\Lib\site-packages\pandas\core\frame.py:5258, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5110 def drop(
#    5111     self,
#    5112     labels: IndexLabel = None,
#    (...)
#    5119     errors: IgnoreRaise = "raise",
#    5120 ) -> DataFrame | None:
#    5121     """
#    5122     Drop specified labels from rows or columns.
#    5123
#    (...)
#    5256             weight  1.0     0.8
#    5257     """
# -> 5258     return super().drop(
#    5259         labels=labels,
#    5260         axis=axis,
#    5261         index=index,
#    5262         columns=columns,
#    5263         level=level,
# ...

# %%
# Removing row
my_df2.drop(2,axis =0, inplace=True)

# %%
my_df2
# Out:
#   School_Year  Busbreakdown_ID  Run_Type Bus_No Route_Number         Reason  \
# 0   2015-2016          1224901  Pre-K/EI    811            1          Other
# 1   2015-2016          1225098  Pre-K/EI   9302            1  Heavy Traffic
# 3   2015-2016          1215511  Pre-K/EI    331            2          Other
# 4   2015-2016          1215828  Pre-K/EI    332            2          Other
#
#   Schools_Serviced             Occurred_On              Created_On   Boro  \
# 0             C353  10/26/2015 08:30:00 AM  10/26/2015 08:40:00 AM  Bronx
# 1             C814  10/27/2015 07:10:00 AM  10/27/2015 07:11:00 AM  Bronx
# 3             C178  09/17/2015 08:08:00 AM  09/17/2015 08:12:00 AM  Bronx
# 4             S176  09/18/2015 07:39:00 AM  09/18/2015 07:45:00 AM  Bronx
#
#    ... How_Long_Delayed Number_Of_Students_On_The_Bus  \
# 0  ...        10MINUTES                             5
# 1  ...       25 MINUTES                             3
# ...
