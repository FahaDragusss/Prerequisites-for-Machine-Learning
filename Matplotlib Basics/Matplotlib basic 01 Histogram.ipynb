# %%
import pandas as pd
import numpy as np
from numpy.random import randn
import matplotlib.pyplot as plt
# %matplotlib inline

# Create a DataFrame
my_df = pd.DataFrame(randn(100, 4), columns=['Mon', 'Tues', 'Wed', 'Thur'])
my_df
# Out:
#          Mon      Tues       Wed      Thur
# 0  -1.858240  0.376023  0.532412 -0.578502
# 1  -1.125748 -1.688087  0.844322 -2.696442
# 2   0.891769 -0.224024 -1.037913  0.288702
# 3  -0.495429  0.235076  0.475680 -0.524938
# 4  -1.323591 -1.100437 -1.033933  1.026581
# ..       ...       ...       ...       ...
# 95  1.191883 -0.266923  0.241015 -0.809872
# 96 -1.047935 -0.325355 -0.256556  0.440772
# 97 -0.305277  0.238776 -0.309407  0.986649
# 98 -0.491458  1.481245 -0.024631  0.474030
# 99  0.760503 -1.054640  0.134890 -0.055601
#
# [100 rows x 4 columns]

# %%
# Histograms
my_df['Wed'].hist()
# Out:
# <Axes: >

# %%
# Histograms with more bins
my_df['Wed'].hist(bins=20)
# Out:
# <Axes: >

# %%
# Another way without grid bars
my_df['Wed'].plot(kind='hist', bins=20)
# Out:
# <Axes: ylabel='Frequency'>

# %%
my_df['Wed'].plot(kind='hist', bins=20, grid=True, legend=True)
# Out:
# <Axes: ylabel='Frequency'>
