# %%
import pandas as pd
import numpy as np
from numpy.random import randn
import matplotlib.pyplot as plt
# %matplotlib inline

# Create a DataFrame
my_df = pd.DataFrame(randn(100, 4), columns=['Mon', 'Tues', 'Wed', 'Thur'])
my_df
# Out:
#          Mon      Tues       Wed      Thur
# 0  -1.673912 -0.851273  0.211694 -0.941450
# 1   0.878329 -1.267101 -1.813236  0.843428
# 2  -0.566090  1.172721  1.060100 -0.865085
# 3   0.674615 -0.077046 -0.897418 -0.951559
# 4   0.481296 -1.098454  0.148695  0.226842
# ..       ...       ...       ...       ...
# 95  0.885585 -0.106502  0.458669  1.171977
# 96  0.343394 -0.227944  0.326787 -0.172391
# 97  0.395142 -1.091121  1.146191 -1.126633
# 98  1.257856  0.434437 -0.260363 -0.192148
# 99  0.662036  1.392894  0.400124  0.626055
#
# [100 rows x 4 columns]

# %%
# Histograms
my_df['Wed'].hist()
# Out:
# <Axes: >

# %%
# Histograms with more bins
my_df['Wed'].hist(bins=20)
# Out:
# <Axes: >

# %%
# Another way without grid bars
my_df['Wed'].plot(kind='hist', bins=20)
# Out:
# <Axes: ylabel='Frequency'>

# %%
my_df['Wed'].plot(kind='hist', bins=20, grid=True, legend=True)
# Out:
# <Axes: ylabel='Frequency'>
