# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from numpy.random import randn

my_df = pd.DataFrame(randn(500, 4), columns=['A', 'B','C','D'])
my_df
# Out:
#             A         B         C         D
# 0   -0.798139  0.382146 -0.360927 -1.365767
# 1   -0.140118 -0.234937  0.903415  0.187659
# 2    0.006857 -0.410217  0.149921  1.220497
# 3   -0.796657  0.079355  0.802057 -1.605658
# 4    0.104626  0.457836 -0.941692  0.343125
# ..        ...       ...       ...       ...
# 495 -1.111527  0.294739  0.163940 -0.839556
# 496  1.871819 -0.527446  1.916356  0.284272
# 497  2.432853  1.547304  0.745872 -0.149432
# 498 -1.074106  1.641328  1.535807 -1.436241
# 499  0.447027 -0.472268  1.007114 -0.448751
#
# [500 rows x 4 columns]

# %%
# Hex bin
my_df.plot(kind='hexbin', x = 'A',y = 'B')
# Out:
# <Axes: xlabel='A', ylabel='B'>

# %%
# Grid size
my_df.plot(kind='hexbin', x = 'A',y = 'B', gridsize=25)
# Out:
# <Axes: xlabel='A', ylabel='B'>
