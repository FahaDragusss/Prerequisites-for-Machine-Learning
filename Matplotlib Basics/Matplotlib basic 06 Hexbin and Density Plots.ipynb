# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from numpy.random import randn
import scipy as sp

my_df = pd.DataFrame(randn(500, 4), columns=['A', 'B','C','D'])
my_df
# Out:
#             A         B         C         D
# 0   -0.986296  0.284199 -1.591800  1.688368
# 1    1.203377  0.375869 -0.010586  1.544908
# 2    0.174256  0.510980  1.834509 -1.052531
# 3   -1.468664 -0.691016 -0.091722  1.049348
# 4   -0.254332 -0.683113  0.173132  1.292973
# ..        ...       ...       ...       ...
# 495  0.435143  1.435377 -1.993289 -0.388304
# 496 -1.836330  0.247433  0.392839  1.284939
# 497  0.401357 -1.193246  0.515681  0.768534
# 498  0.913947  2.172953  0.513320  0.227579
# 499 -0.147595 -0.666996  0.135475  0.509767
#
# [500 rows x 4 columns]

# %%
# Hex bin
my_df.plot(kind='hexbin', x = 'A',y = 'B')
# Out:
# <Axes: xlabel='A', ylabel='B'>

# %%
# Grid size
my_df.plot(kind='hexbin', x = 'A',y = 'B', gridsize=25)
# Out:
# <Axes: xlabel='A', ylabel='B'>

# %%
# Kernel density estimation
my_df.plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
# Density plot
my_df.plot(kind='density')
# Out:
# <Axes: ylabel='Density'>
