# %%
import pandas as pd
import numpy as np
from numpy.random import randn
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
my_df = pd.DataFrame(randn(500,4), columns = ['A', 'B', 'C', 'D'])
my_df
# Out:
#             A         B         C         D
# 0   -0.238744 -0.102407  0.325968  0.517805
# 1   -0.596059 -1.456607  1.035184  1.581332
# 2    1.216003 -1.184443  0.899194 -0.359891
# 3    0.339774  0.964209 -0.779896 -0.198956
# 4   -1.502699 -0.143593  0.565244 -0.378647
# ..        ...       ...       ...       ...
# 495  1.272903 -2.550013  0.860440 -0.846258
# 496  1.997243  0.851964  1.556147 -0.507622
# 497  0.582097  0.512351  0.679320 -1.219427
# 498  0.031022  0.841859 -0.356903  1.110879
# 499 -0.619736 -1.842079 -0.557110 -1.424437
#
# [500 rows x 4 columns]

# %%
# Box plots
my_df.plot.box()
# Out:
# <Axes: >

# %%
# Boxplots size
my_df.plot.box(figsize=(10,6))
# Out:
# <Axes: >

# %%
# Boxplots color
my_df.plot(kind='box', title = " My Boxplot", color = {'medians': 'r', 'boxes': 'b', 'whiskers': 'g', 'caps': 'black'})
# Out:
# <Axes: title={'center': ' My Boxplot'}>
